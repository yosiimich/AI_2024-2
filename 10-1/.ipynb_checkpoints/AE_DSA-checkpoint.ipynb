# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.stats import skew
import os
import csv
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv("C:/Users/yosim/Desktop/2024-2/AI_2024-2/09-24/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df = df.drop(['people'], axis=1)
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 9115  4.033226e-02     0.200829     -0.040701      0.297666     0.708480
# 9116  2.212497e-02     0.148745     -0.266377      0.224716     0.554670
# 9117  9.656444e-02     0.310748     -0.009505     -0.237786     0.088854
# 9118  2.448990e-02     0.156493      0.050624      0.533023     0.677800
# 9119  5.251176e-02     0.229154     -0.342228      0.491919     0.707920
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729     sitting
# 1       -0.059589  7.032302e-07     0.000839      0.347471     sitting
# 2       -0.059065  6.268222e-07     0.000792      0.045579     sitting
# 3       -0.058310  8.011245e-07     0.000895      0.240690     sitting
# 4       -0.057815  6.853423e-07     0.000828      0.258429     sitting
# ...           ...           ...          ...           ...         ...
# 9115    -0.117430  4.135451e-02     0.203358     -0.310022  basketBall
# 9116    -0.250950  3.355704e-02     0.183186     -0.736410  basketBall
# 9117    -0.477260  2.026107e-02     0.142341      0.668438  basketBall
# 9118     0.055941  1.356379e-02     0.116464     -1.482489  basketBall
# 9119     0.251280  9.358254e-03     0.096738     -0.223302  basketBall
#
# [9120 rows x 271 columns]

# %%
df['activity'].value_counts()
# Out:
# activity
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: count, dtype: int64

# %%
df_filtered = df[df['activity'].isin(['sitting', 'jumping'])]
df_filtered
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 8635     9.298029     32.4980     -6.0782  134.634624   11.603216
# 8636     8.738784     34.0480     -6.7822  145.225186   12.050941
# 8637     9.404261     34.8670     -5.3331  130.142955   11.408022
# 8638     9.139112     32.5060     -6.8835  135.812815   11.653876
# 8639     8.868404     30.9070     -6.7151  128.743919   11.346538
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150     1.18320     0.99744    0.002208  ...
# 1        0.552416     1.140865     1.21290     1.05810    0.000784  ...
# 2        0.100538     1.140962     1.21280     1.07960    0.000508  ...
# 3       -0.231914     1.165260     1.31700     1.07870    0.002173  ...
# 4        2.042285     1.187504     1.25740     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 8635     0.570723    -2.592341     1.73230   -12.91800    9.207424  ...
# 8636     0.760224    -2.417799     1.19030   -10.90200    9.233904  ...
# 8637     0.560963    -2.408945     0.81347    -8.21750    6.635468  ...
# 8638     0.589304    -2.359531     1.32350    -9.57930    7.510565  ...
# 8639     0.585457    -2.144665     0.93113    -8.52640    6.022491  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 8635  9.303061e-04     0.030501      0.334449      0.625187     0.691300
# 8636  9.968638e-04     0.031573      0.396417      0.624749     0.693560
# 8637  9.194098e-04     0.030322      0.524964      0.631822     0.690120
# 8638  5.788992e-04     0.024060      0.301200      0.624196     0.688560
# 8639  5.366838e-04     0.023166      0.395776      0.633913     0.692860
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729   sitting
# 1       -0.059589  7.032302e-07     0.000839      0.347471   sitting
# 2       -0.059065  6.268222e-07     0.000792      0.045579   sitting
# 3       -0.058310  8.011245e-07     0.000895      0.240690   sitting
# 4       -0.057815  6.853423e-07     0.000828      0.258429   sitting
# ...           ...           ...          ...           ...       ...
# 8635     0.571870  9.188517e-04     0.030313      0.274486   jumping
# 8636     0.570400  9.632708e-04     0.031037      0.433661   jumping
# 8637     0.581970  8.933477e-04     0.029889      0.335023   jumping
# 8638     0.573620  1.025797e-03     0.032028      0.272121   jumping
# 8639     0.586420  9.165240e-04     0.030274      0.342332   jumping
#
# [960 rows x 271 columns]

# %%
df_filtered['activity'].value_counts()
# Out:
# activity
# sitting    480
# jumping    480
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df_filtered['activity'] = label_encoder.fit_transform(df_filtered['activity'])
# Out:
# C:\Users\yosim\AppData\Local\Temp\ipykernel_10312\1528171052.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['activity'] = label_encoder.fit_transform(df_filtered['activity'])

# %%
df_filtered['activity'].value_counts()
# Out:
# activity
# 1    480
# 0    480
# Name: count, dtype: int64

# %%
df_filtered
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 8635     9.298029     32.4980     -6.0782  134.634624   11.603216
# 8636     8.738784     34.0480     -6.7822  145.225186   12.050941
# 8637     9.404261     34.8670     -5.3331  130.142955   11.408022
# 8638     9.139112     32.5060     -6.8835  135.812815   11.653876
# 8639     8.868404     30.9070     -6.7151  128.743919   11.346538
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150     1.18320     0.99744    0.002208  ...
# 1        0.552416     1.140865     1.21290     1.05810    0.000784  ...
# 2        0.100538     1.140962     1.21280     1.07960    0.000508  ...
# 3       -0.231914     1.165260     1.31700     1.07870    0.002173  ...
# 4        2.042285     1.187504     1.25740     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 8635     0.570723    -2.592341     1.73230   -12.91800    9.207424  ...
# 8636     0.760224    -2.417799     1.19030   -10.90200    9.233904  ...
# 8637     0.560963    -2.408945     0.81347    -8.21750    6.635468  ...
# 8638     0.589304    -2.359531     1.32350    -9.57930    7.510565  ...
# 8639     0.585457    -2.144665     0.93113    -8.52640    6.022491  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 8635  9.303061e-04     0.030501      0.334449      0.625187     0.691300
# 8636  9.968638e-04     0.031573      0.396417      0.624749     0.693560
# 8637  9.194098e-04     0.030322      0.524964      0.631822     0.690120
# 8638  5.788992e-04     0.024060      0.301200      0.624196     0.688560
# 8639  5.366838e-04     0.023166      0.395776      0.633913     0.692860
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729         1
# 1       -0.059589  7.032302e-07     0.000839      0.347471         1
# 2       -0.059065  6.268222e-07     0.000792      0.045579         1
# 3       -0.058310  8.011245e-07     0.000895      0.240690         1
# 4       -0.057815  6.853423e-07     0.000828      0.258429         1
# ...           ...           ...          ...           ...       ...
# 8635     0.571870  9.188517e-04     0.030313      0.274486         0
# 8636     0.570400  9.632708e-04     0.031037      0.433661         0
# 8637     0.581970  8.933477e-04     0.029889      0.335023         0
# 8638     0.573620  1.025797e-03     0.032028      0.272121         0
# 8639     0.586420  9.165240e-04     0.030274      0.342332         0
#
# [960 rows x 271 columns]

# %%
LABELS = ["Normal", "Abnormal"]

# %%
import matplotlib.pyplot as plt
count_classes = pd.value_counts(df_filtered['activity'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# C:\Users\yosim\AppData\Local\Temp\ipykernel_10312\2263403013.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df_filtered['activity'], sort = True)

# %%
abnormal = df_filtered[df_filtered.activity == 0]
normal = df_filtered[df_filtered.activity == 1]
print(abnormal.shape,normal.shape)
# Out:
# (480, 271) (480, 271)

# %%
X_train, X_test = train_test_split(df_filtered, test_size=0.2, random_state=42)

# %%
X_train, X_valid = train_test_split(X_train, test_size=0.2, random_state=42)

# %%
X_train = X_train[X_train.activity==1]
X_train = X_train.drop(['activity'], axis=1)

X_valid = X_valid[X_valid.activity==1]
X_valid = X_valid.drop(['activity'], axis=1)

# %%
y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1)

# %%
input_dim = X_train.shape[1]
input_dim
# Out:
# 270

# %%
encoding_dim = input_dim // 4  

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
encoded = Dense(int(encoding_dim / 2) activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
history = autoencoder.fit(X_train, X_train, 
                          epochs=100, 
                          batch_size=32, 
                          shuffle=True, 
                          validation_data=(X_valid, X_valid))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 44ms/step - loss: 5.4512 - val_loss: 5.3912
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 5.0678 - val_loss: 4.9596
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.7150 - val_loss: 4.7646
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.6210 - val_loss: 4.7496
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.6153 - val_loss: 4.7475
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.6133 - val_loss: 4.7451
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.6110 - val_loss: 4.7422
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.6091 - val_loss: 4.7407
# Epoch 9/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.6078 - val_loss: 4.7392
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.6068 - val_loss: 4.7379
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.6044 - val_loss: 4.7331
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.6014 - val_loss: 4.7314
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5999 - val_loss: 4.7295
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5988 - val_loss: 4.7287
# Epoch 15/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5981 - val_loss: 4.7282
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5976 - val_loss: 4.7275
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5972 - val_loss: 4.7272
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5968 - val_loss: 4.7268
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5966 - val_loss: 4.7267
# Epoch 20/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5964 - val_loss: 4.7265
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5961 - val_loss: 4.7263
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5958 - val_loss: 4.7261
# Epoch 23/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5954 - val_loss: 4.7256
# Epoch 24/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5949 - val_loss: 4.7251
# Epoch 25/100
# 10/10 [==============================] - 0s 12ms/step - loss: 4.5942 - val_loss: 4.7249
# Epoch 26/100
# 10/10 [==============================] - 0s 11ms/step - loss: 4.5938 - val_loss: 4.7246
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5934 - val_loss: 4.7239
# Epoch 28/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5924 - val_loss: 4.7233
# Epoch 29/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5919 - val_loss: 4.7232
# Epoch 30/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5916 - val_loss: 4.7223
# Epoch 31/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5907 - val_loss: 4.7217
# Epoch 32/100
# 10/10 [==============================] - 0s 11ms/step - loss: 4.5903 - val_loss: 4.7217
# Epoch 33/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5900 - val_loss: 4.7210
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5898 - val_loss: 4.7211
# Epoch 35/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5895 - val_loss: 4.7208
# Epoch 36/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5894 - val_loss: 4.7207
# Epoch 37/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5893 - val_loss: 4.7206
# Epoch 38/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5891 - val_loss: 4.7204
# Epoch 39/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5890 - val_loss: 4.7204
# Epoch 40/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5888 - val_loss: 4.7201
# Epoch 41/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5887 - val_loss: 4.7201
# Epoch 42/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5886 - val_loss: 4.7200
# Epoch 43/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5885 - val_loss: 4.7201
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5885 - val_loss: 4.7201
# Epoch 45/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5884 - val_loss: 4.7200
# Epoch 46/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5883 - val_loss: 4.7199
# Epoch 47/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5882 - val_loss: 4.7200
# Epoch 48/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5882 - val_loss: 4.7199
# Epoch 49/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5881 - val_loss: 4.7200
# Epoch 50/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5881 - val_loss: 4.7198
# Epoch 51/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5880 - val_loss: 4.7198
# Epoch 52/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5879 - val_loss: 4.7198
# Epoch 53/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5879 - val_loss: 4.7198
# Epoch 54/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5879 - val_loss: 4.7197
# Epoch 55/100
# 10/10 [==============================] - 0s 11ms/step - loss: 4.5878 - val_loss: 4.7197
# Epoch 56/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5878 - val_loss: 4.7197
# Epoch 57/100
# 10/10 [==============================] - 0s 11ms/step - loss: 4.5877 - val_loss: 4.7196
# Epoch 58/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5877 - val_loss: 4.7196
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5877 - val_loss: 4.7196
# Epoch 60/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5876 - val_loss: 4.7195
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5876 - val_loss: 4.7195
# Epoch 62/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5876 - val_loss: 4.7196
# Epoch 63/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5875 - val_loss: 4.7194
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5875 - val_loss: 4.7195
# Epoch 65/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5875 - val_loss: 4.7195
# Epoch 66/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5874 - val_loss: 4.7195
# Epoch 67/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5874 - val_loss: 4.7195
# Epoch 68/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5873 - val_loss: 4.7195
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5873 - val_loss: 4.7195
# Epoch 70/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5873 - val_loss: 4.7194
# Epoch 71/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5872 - val_loss: 4.7193
# Epoch 72/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5871 - val_loss: 4.7194
# Epoch 73/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5871 - val_loss: 4.7194
# Epoch 74/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5871 - val_loss: 4.7192
# Epoch 75/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5870 - val_loss: 4.7193
# Epoch 76/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5870 - val_loss: 4.7193
# Epoch 77/100
# 10/10 [==============================] - 0s 13ms/step - loss: 4.5869 - val_loss: 4.7192
# Epoch 78/100
# 10/10 [==============================] - 0s 11ms/step - loss: 4.5869 - val_loss: 4.7193
# Epoch 79/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5868 - val_loss: 4.7191
# Epoch 80/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5868 - val_loss: 4.7190
# Epoch 81/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5867 - val_loss: 4.7191
# Epoch 82/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5867 - val_loss: 4.7189
# Epoch 83/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5866 - val_loss: 4.7189
# Epoch 84/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5865 - val_loss: 4.7190
# Epoch 85/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5865 - val_loss: 4.7189
# Epoch 86/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5865 - val_loss: 4.7188
# Epoch 87/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5865 - val_loss: 4.7187
# Epoch 88/100
# 10/10 [==============================] - 0s 7ms/step - loss: 4.5864 - val_loss: 4.7187
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5864 - val_loss: 4.7186
# Epoch 90/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5864 - val_loss: 4.7184
# Epoch 91/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5863 - val_loss: 4.7183
# Epoch 92/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5863 - val_loss: 4.7186
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 4.5863 - val_loss: 4.7185
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5862 - val_loss: 4.7185
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 4.5862 - val_loss: 4.7183
# Epoch 96/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5861 - val_loss: 4.7181
# Epoch 97/100
# 10/10 [==============================] - 0s 10ms/step - loss: 4.5862 - val_loss: 4.7181
# Epoch 98/100
# 10/10 [==============================] - 0s 9ms/step - loss: 4.5861 - val_loss: 4.7176
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5860 - val_loss: 4.7179
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 4.5859 - val_loss: 4.7182

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 6/6 [==============================] - 0s 3ms/step
#        reconstruction_error  true_class
# count            192.000000  192.000000
# mean             292.118317    0.447917
# std              436.459366    0.498580
# min                4.402665    0.000000
# 25%                4.567034    0.000000
# 50%               70.791778    0.000000
# 75%              493.254404    1.000000
# max             2929.357921    1.000000

# %%
threshold = 15

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     106.0
#            1       0.00      0.00      0.00      86.0
#
#     accuracy                           0.00     192.0
#    macro avg       0.00      0.00      0.00     192.0
# weighted avg       0.00      0.00      0.00     192.0
