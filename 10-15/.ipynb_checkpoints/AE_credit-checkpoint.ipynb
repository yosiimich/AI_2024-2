# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
df=pd.read_csv('./creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# False

# %%
LABELS = ["Normal", "Fraud"]

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# C:\Users\yosim\AppData\Local\Temp\ipykernel_23588\2107955042.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df['Class'], sort = True)

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
data = df.drop(['Amount'],axis=1)
data = data.drop(['Time'],axis=1)
data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.251412 -0.018307
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.524980  0.247998
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  1.475829  0.213454
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.059616  0.214205
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.001396  0.232045
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.127434  0.265245
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.382948  0.261057
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 29 columns]

# %%
RANDOM_SEED = 42

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

X_train.shape
# Out:
# (227451, 28)

# %%
# 오토인코더 모델 
# 리니어 모델

input_dim = X_train.shape[1]
encoding_dim = 64  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train, X_train, 
                          epochs=50, 
                          batch_size=128, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.8122 - val_loss: 0.7366
# Epoch 2/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7528 - val_loss: 0.7312
# Epoch 3/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7492 - val_loss: 0.7279
# Epoch 4/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7471 - val_loss: 0.7270
# Epoch 5/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7465 - val_loss: 0.7267
# Epoch 6/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7457 - val_loss: 0.7229
# Epoch 7/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7424 - val_loss: 0.7226
# Epoch 8/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7423 - val_loss: 0.7227
# Epoch 9/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7401 - val_loss: 0.7199
# Epoch 10/50
# 1600/1600 [==============================] - 2s 984us/step - loss: 0.7391 - val_loss: 0.7195
# Epoch 11/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7390 - val_loss: 0.7196
# Epoch 12/50
# 1600/1600 [==============================] - 2s 998us/step - loss: 0.7390 - val_loss: 0.7196
# Epoch 13/50
# 1600/1600 [==============================] - 2s 997us/step - loss: 0.7390 - val_loss: 0.7199
# Epoch 14/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7390 - val_loss: 0.7195
# Epoch 15/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7389 - val_loss: 0.7195
# Epoch 16/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7389 - val_loss: 0.7193
# Epoch 17/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7388 - val_loss: 0.7194
# Epoch 18/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7388 - val_loss: 0.7193
# Epoch 19/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7388 - val_loss: 0.7194
# Epoch 20/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7388 - val_loss: 0.7194
# Epoch 21/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7388 - val_loss: 0.7193
# Epoch 22/50
# 1600/1600 [==============================] - 2s 995us/step - loss: 0.7388 - val_loss: 0.7193
# Epoch 23/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7388 - val_loss: 0.7194
# Epoch 24/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7387 - val_loss: 0.7193
# Epoch 25/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7387 - val_loss: 0.7192
# Epoch 26/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7394 - val_loss: 0.7193
# Epoch 27/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7387 - val_loss: 0.7194
# Epoch 28/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7387 - val_loss: 0.7193
# Epoch 29/50
# 1600/1600 [==============================] - 2s 989us/step - loss: 0.7387 - val_loss: 0.7194
# Epoch 30/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7387 - val_loss: 0.7194
# Epoch 31/50
# 1600/1600 [==============================] - 2s 988us/step - loss: 0.7387 - val_loss: 0.7193
# Epoch 32/50
# 1600/1600 [==============================] - 2s 987us/step - loss: 0.7387 - val_loss: 0.7192
# Epoch 33/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7387 - val_loss: 0.7192
# Epoch 34/50
# 1600/1600 [==============================] - 2s 997us/step - loss: 0.7387 - val_loss: 0.7192
# Epoch 35/50
# 1600/1600 [==============================] - 2s 984us/step - loss: 0.7387 - val_loss: 0.7195
# Epoch 36/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7387 - val_loss: 0.7193
# Epoch 37/50
# 1600/1600 [==============================] - 2s 991us/step - loss: 0.7389 - val_loss: 0.7193
# Epoch 38/50
# 1600/1600 [==============================] - 2s 996us/step - loss: 0.7386 - val_loss: 0.7192
# Epoch 39/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7192
# Epoch 40/50
# 1600/1600 [==============================] - 2s 987us/step - loss: 0.7386 - val_loss: 0.7214
# Epoch 41/50
# 1600/1600 [==============================] - 2s 991us/step - loss: 0.7387 - val_loss: 0.7195
# Epoch 42/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7197
# Epoch 43/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7191
# Epoch 44/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7193
# Epoch 45/50
# 1600/1600 [==============================] - 2s 992us/step - loss: 0.7386 - val_loss: 0.7192
# Epoch 46/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7192
# Epoch 47/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7192
# Epoch 48/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7194
# Epoch 49/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7193
# Epoch 50/50
# 1600/1600 [==============================] - 2s 1ms/step - loss: 0.7386 - val_loss: 0.7192

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 1781/1781 [==============================] - 1s 741us/step
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.770600      0.001720
# std                3.685499      0.041443
# min                0.027920      0.000000
# 25%                0.217242      0.000000
# 50%                0.383093      0.000000
# 75%                0.634479      0.000000
# max              266.790586      1.000000

# %%
error_df.head()
# Out:
#         reconstruction_error  true_class
# 43428              83.115781           1
# 49906               0.824154           0
# 29474               0.191099           0
# 276481              0.335209           0
# 278846              0.175813           0

# %%
threshold = 15

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.15      0.36      0.21        98
#
#     accuracy                           1.00     56962
#    macro avg       0.58      0.68      0.61     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# # Non - linear

# %%
# 오토인코더 모델 
# 리니어 모델

input_dim = X_train.shape[1]
encoding_dim = 64  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(32, activation='relu')(input_layer)
encoded = Dense(16, activation='relu')(encoded)
decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(16, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train, X_train, 
                          epochs=50, 
                          batch_size=128, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632896.0000 - val_loss: 363167232.0000
# Epoch 2/50
# 1803/1803 [==============================] - 2s 976us/step - loss: 362632768.0000 - val_loss: 363167232.0000
# Epoch 3/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632448.0000 - val_loss: 363167232.0000
# Epoch 4/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632544.0000 - val_loss: 363167232.0000
# Epoch 5/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632064.0000 - val_loss: 363167232.0000
# Epoch 6/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632736.0000 - val_loss: 363167232.0000
# Epoch 7/50
# 1803/1803 [==============================] - 2s 988us/step - loss: 362632224.0000 - val_loss: 363167232.0000
# Epoch 8/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632864.0000 - val_loss: 363167232.0000
# Epoch 9/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632704.0000 - val_loss: 363167232.0000
# Epoch 10/50
# 1803/1803 [==============================] - 2s 990us/step - loss: 362632416.0000 - val_loss: 363167232.0000
# Epoch 11/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632640.0000 - val_loss: 363167232.0000
# Epoch 12/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632224.0000 - val_loss: 363167232.0000
# Epoch 13/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632416.0000 - val_loss: 363167232.0000
# Epoch 14/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362633088.0000 - val_loss: 363167232.0000
# Epoch 15/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632736.0000 - val_loss: 363167232.0000
# Epoch 16/50
# 1803/1803 [==============================] - 2s 988us/step - loss: 362632320.0000 - val_loss: 363167232.0000
# Epoch 17/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632480.0000 - val_loss: 363167232.0000
# Epoch 18/50
# 1803/1803 [==============================] - 2s 990us/step - loss: 362632832.0000 - val_loss: 363167232.0000
# Epoch 19/50
# 1803/1803 [==============================] - 2s 998us/step - loss: 362632864.0000 - val_loss: 363167232.0000
# Epoch 20/50
# 1803/1803 [==============================] - 2s 996us/step - loss: 362633088.0000 - val_loss: 363167232.0000
# Epoch 21/50
# 1803/1803 [==============================] - 2s 978us/step - loss: 362632768.0000 - val_loss: 363167232.0000
# Epoch 22/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632224.0000 - val_loss: 363167232.0000
# Epoch 23/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632480.0000 - val_loss: 363167232.0000
# Epoch 24/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632704.0000 - val_loss: 363167232.0000
# Epoch 25/50
# 1803/1803 [==============================] - 2s 981us/step - loss: 362632544.0000 - val_loss: 363167232.0000
# Epoch 26/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632608.0000 - val_loss: 363167232.0000
# Epoch 27/50
# 1803/1803 [==============================] - 2s 990us/step - loss: 362632672.0000 - val_loss: 363167232.0000
# Epoch 28/50
# 1803/1803 [==============================] - 2s 1000us/step - loss: 362632448.0000 - val_loss: 363167232.0000
# Epoch 29/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632992.0000 - val_loss: 363167232.0000
# Epoch 30/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632928.0000 - val_loss: 363167232.0000
# Epoch 31/50
# 1803/1803 [==============================] - 2s 981us/step - loss: 362632480.0000 - val_loss: 363167232.0000
# Epoch 32/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632544.0000 - val_loss: 363167232.0000
# Epoch 33/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632672.0000 - val_loss: 363167232.0000
# Epoch 34/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632384.0000 - val_loss: 363167232.0000
# Epoch 35/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632672.0000 - val_loss: 363167232.0000
# Epoch 36/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632960.0000 - val_loss: 363167232.0000
# Epoch 37/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632896.0000 - val_loss: 363167232.0000
# Epoch 38/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632544.0000 - val_loss: 363167232.0000
# Epoch 39/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632544.0000 - val_loss: 363167232.0000
# Epoch 40/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632096.0000 - val_loss: 363167232.0000
# Epoch 41/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632448.0000 - val_loss: 363167232.0000
# Epoch 42/50
# 1803/1803 [==============================] - 2s 973us/step - loss: 362632480.0000 - val_loss: 363167232.0000
# Epoch 43/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632544.0000 - val_loss: 363167232.0000
# Epoch 44/50
# 1803/1803 [==============================] - 2s 979us/step - loss: 362632384.0000 - val_loss: 363167232.0000
# Epoch 45/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632416.0000 - val_loss: 363167232.0000
# Epoch 46/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632768.0000 - val_loss: 363167232.0000
# Epoch 47/50
# 1803/1803 [==============================] - 2s 998us/step - loss: 362632352.0000 - val_loss: 363167232.0000
# Epoch 48/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632672.0000 - val_loss: 363167232.0000
# Epoch 49/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632480.0000 - val_loss: 363167232.0000
# Epoch 50/50
# 1803/1803 [==============================] - 2s 1ms/step - loss: 362632384.0000 - val_loss: 363167232.0000

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 891/891 [==============================] - 1s 700us/step
#        reconstruction_error    true_class
# count          2.848100e+04  56962.000000
# mean           3.631310e+08      0.001720
# std            2.946018e+08      0.041443
# min            1.217982e+00      0.000000
# 25%            9.529856e+07      0.000000
# 50%            2.310230e+08      0.000000
# 75%            6.263280e+08      0.000000
# max            9.630078e+08      1.000000

# %%
threshold = 15

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67     56864
#            1       0.00      0.47      0.00        98
#
#     accuracy                           0.50     56962
#    macro avg       0.50      0.48      0.33     56962
# weighted avg       1.00      0.50      0.67     56962

# %% [markdown]
# # using noise

# %%
df_total = df

# %%
df_total = df_total.drop(['Time'],axis=1)

# %%
df_total = df_total.drop(['Amount'],axis=1)

# %%
No_noise_df = df_total

# %%
noise_factor = 0.5

# %%
for name in list(df_total.columns):
    df_total[name]=df_total[name]+ noise_factor * np.random.normal(loc=0.0, scale=1.0, size=1)

# %%
df_total
# Out:
#                V1        V2        V3        V4        V5        V6        V7  \
# 0       -1.686663 -0.228437  2.830381  1.355966  0.348842 -0.337128  0.020044
# 1        0.865002  0.110495  0.460515  0.425965  0.747181 -0.881877 -0.298357
# 2       -1.685210 -1.495819  2.067244  0.357591  0.183965  1.000983  0.571907
# 3       -1.293127 -0.340882  2.087028 -0.885480  0.676854  0.447687  0.018055
# 4       -1.485089  0.722081  1.842753  0.380845  0.279970 -0.703594  0.373386
# ...           ...       ...       ...       ...       ...       ...       ...
# 284802 -12.207973  9.916129 -9.540749 -2.088845 -4.677310 -3.406353 -5.137770
# 284803  -1.059644 -0.210737  2.329064 -0.760777  1.555393  0.258899 -0.195225
# 284804   1.592710 -0.456910 -2.955605 -0.580017  3.317678  2.231744 -0.516381
# 284805  -0.567296  0.374826  0.996545  0.667610  0.309202 -0.175808 -0.905734
# 284806  -0.860268 -0.345390  0.997372 -0.528460  0.674617 -1.449133  1.357452
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 0      -0.099881  0.303265  0.555200  ...  0.426388 -0.935160 -0.002046
# 1      -0.113477 -0.315947  0.297431  ...  0.105893 -1.142629 -0.918556
# 2       0.049097 -1.575176  0.672048  ...  0.699956 -0.668855  0.491796
# 3       0.178857 -1.447546  0.409453  ... -0.033062 -1.025154 -0.274610
# 4      -0.469111  0.757217  1.217480  ...  0.583518 -0.926284  0.518395
# ...          ...       ...       ...  ...       ...       ...       ...
# 284802  7.106755  1.853906  4.820576  ...  1.650805 -0.703399 -0.168020
# 284803  0.096290  0.524278 -0.511521  ...  0.234592 -0.702648  0.644500
# 284804  0.509839  0.371932 -0.020376  ...  0.176372 -0.684808  0.298345
# 284805  0.480567  0.331565  0.065280  ...  0.302410 -0.651608  0.520165
# 284806 -0.613229  0.425658 -0.451021  ...  0.557924 -0.655796  0.363195
#
#              V23       V24       V25       V26       V27       V28    Class
# 0      -0.276341  0.138950 -0.094670 -0.416854  0.190453 -0.135472 -0.48648
# 1      -0.064579 -0.267825 -0.056039 -0.101844  0.047911 -0.099695 -0.48648
# 2       0.743545 -0.617259 -0.550852 -0.366835  0.001542 -0.174171 -0.48648
# 3      -0.356187 -1.103554  0.424166 -0.449668  0.119617 -0.052961 -0.48648
# 4      -0.303325  0.213289 -0.429219  0.274553  0.276317  0.100734 -0.48648
# ...          ...       ...       ...       ...       ...       ...      ...
# 284802  0.848613 -0.437327  1.213597  0.022296  1.000546  0.709312 -0.48648
# 284803 -0.153404 -0.944204 -0.829834 -0.622994  0.125367 -0.167946 -0.48648
# 284804 -0.203368  0.712156  0.042536 -0.315109  0.061349 -0.140980 -0.48648
# 284805 -0.329165  0.195227 -0.792369  0.318930  0.165715 -0.009886 -0.48648
# 284806  0.210910  0.080819 -0.696858 -1.046006  0.054479 -0.100770 -0.48648
#
# [284807 rows x 29 columns]

# %%
X_train, X_test = train_test_split(df_total, test_size=0.1, random_state=42)

X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

X_train.shape, X_test.shape
# Out:
# ((0, 28), (28481, 28))

# %%
X_train2, X_test2 = train_test_split(No_noise_df, test_size=0.1, random_state=42)

X_train2 = X_train2[X_train2.Class == 0]

X_train2 = X_train2.drop(['Class'], axis=1)

y_test2 = X_test2['Class']
X_test2 = X_test2.drop(['Class'], axis=1)

X_train2 = X_train2.values
X_test2 = X_test2.values

X_train2.shape, X_test2.shape
# Out:
# ((0, 28), (28481, 28))
